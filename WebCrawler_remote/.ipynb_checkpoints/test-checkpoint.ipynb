# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import datetime
import time
from fake_useragent import UserAgent
import pandas as pd
import random
import datetime
import logging
import datetime
import smtplib
import mimetypes
from email.mime.multipart import MIMEMultipart
from email import encoders
from email.message import Message
from email.mime.audio import MIMEAudio
from email.mime.base import MIMEBase
from email.mime.image import MIMEImage
from email.mime.text import MIMEText

ua = UserAgent()
today = datetime.date.today().strftime('%Y%m%d')
FORMAT = '%(asctime)s %(levelname)s: %(message)s'
filename = 'C:/Users/Administrator/Desktop/EY_WebCrawler/Error Record/'+today+'ErrorReport.log'

try:
    latest = pd.read_csv('C:/Users/Administrator/Desktop/EY_WebCrawler/標案資料最新紀錄.csv')
    try:
        ldate = latest['公告日'][0]
        today = datetime.date.today().strftime('%Y%m%d')
        ltoday = str(int(today[0:4])-1911)+'/'+today[4:6]+'/'+today[6:8]

        start_date = ldate
        end_date = ltoday
        key_words = ['行銷','數據','顧問','分析']

        final_df = pd.DataFrame([])

        for key_word in key_words:
            print("---------------開始"+key_word+"標案爬蟲---------------")
            param = {"method": "search",
            'searchMethod': 'true',
            'tenderUpdate':'' ,
            'searchTarget':'' ,
            'orgName': '',
            'orgId':'' ,
            'hid_1': '1',
            'tenderName': key_word,
            'tenderId': '',
            'tenderType': 'tenderDeclaration',
            'tenderWay': '1,2,3,4,5,6,7,10,12',
            'tenderDateRadio': 'on',
            'tenderStartDateStr': start_date,
            'tenderEndDateStr': end_date,
            'tenderStartDate': start_date,
            'tenderEndDate': end_date,
            'isSpdt': 'N',
            'proctrgCate': '',
            'btnQuery': '查詢',
            'hadUpdated': ''}

            head = 'https://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=basic&method=search&isSpdt=&pageIndex='

            user_agent = UserAgent()

            headers = {
            "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
            "Accept-Encoding": "gzip, deflate, br",
            "Accept-Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
            "Cache-Control": "max-age=0",
            "Connection": "keep-alive",
            "Host": "web.pcc.gov.tw",
            "Referer": "https://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=basic",
            "Cookie": "NSC_xfc_qfstjtufodf=ffffffff09081f7945525d5f4f58455e445a4a423660; cookiesession1=5135051C4FVUFANQLOEMHML6X8QC5058; JSESSIONID=0000u6QnCl9DTQaxTTMG_SRcSEB:14nuu9h0k; NSC_xfc_jqw6_qfstjtufodf=00000000234c1f310b110d790a110e1122081e113660",
            "sec-ch-ua-mobile": "?0",
            "Sec-Fetch-Dest": "document",
            "Sec-Fetch-Mode": "navigate",
            "Sec-Fetch-Site": "same-origin",
            "Sec-Fetch-User": "?1",
            "Upgrade-Insecure-Requests": "1",
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.106 Safari/537.36"
            }

            my_df = pd.DataFrame([])

            url = head + str(1)
            response = requests.post(url,data = param,headers = headers)
            soup = BeautifulSoup(response.text,features="html.parser")
            test = soup.find_all('a',style="color: #444444;")
            if test==[]:
                pages = 1
            else:
                pages = int(test[-1]['href'][-1])

            for i in range(0,pages):
                time.sleep(15)
                url = head + str(i+1)
                response = requests.post(url,data = param,headers = headers)
                soup = BeautifulSoup(response.text,features="html.parser") 
                data = soup.find_all('a')

                href = []
                title = []

                for i in range(0,len(data)):
                    try:
                        title = title + [data[i]['title']]
                        href = href + [data[i]['href']]
                    except:
                        break

                df = pd.DataFrame({
                    'href':href,
                    'title':title
                })

                ind = []
                for i in range(0,len(df)):
                    if key_word not in df['title'][i]:
                        ind = ind + [i]
                df = df.drop(index = ind)
                my_df = pd.concat([my_df,df])
            my_df = my_df.reset_index()
            amount = len(my_df)
            print("總共{}筆資料,預計約{}分鐘後完成".format(amount,amount*0.25))

            cases = pd.DataFrame([])

            if my_df['title'][0] == '前往 技師與工程技術顧問公司管理資訊系統(另開視窗)':
                my_df = my_df.drop(index = 0).reset_index()
            try:
                headers = {
                "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
                "Accept-Encoding": "gzip, deflate, br",
                "Accept-Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
                "Cache-Control": "max-age=0",
                "Connection": "keep-alive",
                "Host": "web.pcc.gov.tw",
                "Referer": "https://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=basic",
                "Cookie": "NSC_xfc_qfstjtufodf=ffffffff09081f7945525d5f4f58455e445a4a423660; cookiesession1=5135051C4FVUFANQLOEMHML6X8QC5058; JSESSIONID=0000u6QnCl9DTQaxTTMG_SRcSEB:14nuu9h0k; NSC_xfc_jqw6_qfstjtufodf=00000000234c1f310b110d790a110e1122081e113660",
                "sec-ch-ua-mobile": "?0",
                "Sec-Fetch-Dest": "document",
                "Sec-Fetch-Mode": "navigate",
                "Sec-Fetch-Site": "same-origin",
                "Sec-Fetch-User": "?1",
                "Upgrade-Insecure-Requests": "1",
                "User-Agent": ua.random
                }

                for i in range(0,len(my_df)):    
                    time.sleep(15)
                    key = my_df['href'][i].split('F&primaryKey=')[1]
                    web = 'https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey='+str(key)
                    link = requests.get(web,headers = headers)
                    soup = BeautifulSoup(link.text,features="html.parser") 

                    blue = soup.find_all('th',bgcolor="#DAEBED", width="25%")
                    yellow = soup.find_all('th',bgcolor="#FFFF99", width="25%")
                    green = soup.find_all('th',bgcolor="#CAEDAF", width="25%")
                    orange = soup.find_all('th',bgcolor="#FFDD83", width="25%")
                    alist = blue+yellow+green+orange
                    mylist = []
                    for i in range(0,len(alist)):
                        txt = alist[i].text.replace('\r','').replace('\t','').replace('\n','')
                        mylist+=[txt]

                    blist = soup.find_all('td', bgcolor="#EFF1F1",width="75%")[0:len(mylist)]
                    content = []
                    for i in range(0,len(blist)):
                        txt = blist[i].text.replace('\r','').replace('\t','').replace('\n','')
                        content+=[txt]    
                    mylist = mylist + ['連結']
                    content = content + [web]

                    one_case = pd.DataFrame({
                        'content':content
                    },index = mylist)

                    cases = pd.concat([cases,one_case],axis = 1)

                cases = cases.transpose()

                df = pd.DataFrame({
                    'Status':'',
                    '發起人':'Sean',
                    '電子領標':'Rosenna',
                    '電子領標日':'',
                    '公告日':list(cases['公告日']),
                    '截止投標':list(cases['截止投標']),
                    '開標時間':list(cases['開標時間']),
                    '金額':list(cases['預算金額']),
                    'WD':'',
                    '專案結束日':'',
                    '招標方式':list(cases['招標方式']),
                    '決標方式':list(cases['決標方式']),
                    '機關名稱':list(cases['機關名稱']),
                    '單位名稱':list(cases['單位名稱']),
                    '標案名稱':list(cases['標案名稱']),
                    '聯絡人':list(cases['聯絡人']),
                    '聯絡電話':list(cases['聯絡電話']),
                    '電子郵件信箱':list(cases['電子郵件信箱']),
                    '標的分類':list(cases['標的分類']),
                    '連結':list(cases['連結']),
                    '關鍵字':key_word
                })
            except:
                df = pd.DataFrame([])

            final_df = pd.concat([final_df,df])

        final_df = final_df.drop_duplicates(subset = '標案名稱').reset_index().drop(columns = 'index')

        d = final_df['公告日'].copy()
        for i in range(len(d)):
            year = str(int(d[i].split('/')[0])+1911)
            d[i]=year+d[i].split('/')[1]+d[i].split('/')[2]
        d=pd.to_datetime(d,format='%Y%m%d')
        final_df['date'] = d
        final_df = final_df.sort_values(by = 'date',ascending = False)
        final_df = final_df.drop(columns = 'date')
        
        sd = start_date.split('/')[0]+start_date.split('/')[1]+start_date.split('/')[2]
        ed = end_date.split('/')[0]+end_date.split('/')[1]+end_date.split('/')[2]
        final_df.to_csv('C:/Users/Administrator/Desktop/EY_WebCrawler/Daily Bid Data/標案資料'+sd+'-'+ed+'.csv',index = None,encoding = 'utf-8_sig')

        new_data = pd.concat([final_df,latest]).drop_duplicates(subset = '標案名稱')
        new_data = new_data.reset_index().drop(columns = 'index')

        new_data.to_csv('C:/Users/Administrator/Desktop/EY_WebCrawler/標案資料最新紀錄.csv',index = None,encoding = 'utf-8_sig')
        scenario = 1
    except:
        logging.basicConfig(handlers=[logging.FileHandler(filename, 'a', 'utf-8')],level=logging.ERROR, format=FORMAT)
        logging.error('Catch an exception.', exc_info=True)
        scenario = 2
except:
    try:
        print('目前尚無標案紀錄！')
        YN = input('是否進行資料抓取? 請輸入"Y"或"N"')
        while YN not in ['Y','N']:
            YN = input('請輸入正確的字符("Y"或"N")')
        if YN=='Y':
            final_df = pd.DataFrame([])
            start_date = input('請輸入起始時間，格式為:民國年/月/日，例如:109/01/05 ')
            end_date = input('請輸入結束時間，格式為:民國年/月/日，例如:110/12/31 ')
            key_words = ['行銷','數據','顧問','分析']

            for key_word in key_words:
                print("---------------開始"+key_word+"標案爬蟲---------------")
                param = {"method": "search",
                'searchMethod': 'true',
                'tenderUpdate':'' ,
                'searchTarget':'' ,
                'orgName': '',
                'orgId':'' ,
                'hid_1': '1',
                'tenderName': key_word,
                'tenderId': '',
                'tenderType': 'tenderDeclaration',
                'tenderWay': '1,2,3,4,5,6,7,10,12',
                'tenderDateRadio': 'on',
                'tenderStartDateStr': start_date,
                'tenderEndDateStr': end_date,
                'tenderStartDate': start_date,
                'tenderEndDate': end_date,
                'isSpdt': 'N',
                'proctrgCate': '',
                'btnQuery': '查詢',
                'hadUpdated': ''}

                head = 'https://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=basic&method=search&isSpdt=&pageIndex='

                user_agent = UserAgent()

                headers = {
                "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
                "Accept-Encoding": "gzip, deflate, br",
                "Accept-Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
                "Cache-Control": "max-age=0",
                "Connection": "keep-alive",
                "Host": "web.pcc.gov.tw",
                "Referer": "https://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=basic",
                "Cookie": "NSC_xfc_qfstjtufodf=ffffffff09081f7945525d5f4f58455e445a4a423660; cookiesession1=5135051C4FVUFANQLOEMHML6X8QC5058; JSESSIONID=0000u6QnCl9DTQaxTTMG_SRcSEB:14nuu9h0k; NSC_xfc_jqw6_qfstjtufodf=00000000234c1f310b110d790a110e1122081e113660",
                "sec-ch-ua-mobile": "?0",
                "Sec-Fetch-Dest": "document",
                "Sec-Fetch-Mode": "navigate",
                "Sec-Fetch-Site": "same-origin",
                "Sec-Fetch-User": "?1",
                "Upgrade-Insecure-Requests": "1",
                "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.106 Safari/537.36"
                }

                my_df = pd.DataFrame([])

                url = head + str(1)
                response = requests.post(url,data = param,headers = headers)
                soup = BeautifulSoup(response.text,features="html.parser")
                test = soup.find_all('a',style="color: #444444;")
                if test==[]:
                    pages = 1
                else:
                    pages = int(test[-1]['href'][-1])

                for i in range(0,pages):
                    time.sleep(15)
                    url = head + str(i+1)
                    response = requests.post(url,data = param,headers = headers)
                    soup = BeautifulSoup(response.text,features="html.parser") 
                    data = soup.find_all('a')

                    href = []
                    title = []

                    for i in range(0,len(data)):
                        try:
                            title = title + [data[i]['title']]
                            href = href + [data[i]['href']]
                        except:
                            break

                    df = pd.DataFrame({
                        'href':href,
                        'title':title
                    })

                    ind = []
                    for i in range(0,len(df)):
                        if key_word not in df['title'][i]:
                            ind = ind + [i]
                    df = df.drop(index = ind)
                    my_df = pd.concat([my_df,df])
                my_df = my_df.reset_index()
                
                amount = len(my_df)
                print("總共{}筆資料,預計約{}分鐘後完成".format(amount,amount*0.25))

                cases = pd.DataFrame([])

                if my_df['title'][0] == '前往 技師與工程技術顧問公司管理資訊系統(另開視窗)':
                    my_df = my_df.drop(index = 0).reset_index()
                try:
                    headers = {
                    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
                    "Accept-Encoding": "gzip, deflate, br",
                    "Accept-Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
                    "Cache-Control": "max-age=0",
                    "Connection": "keep-alive",
                    "Host": "web.pcc.gov.tw",
                    "Referer": "https://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=basic",
                    "Cookie": "NSC_xfc_qfstjtufodf=ffffffff09081f7945525d5f4f58455e445a4a423660; cookiesession1=5135051C4FVUFANQLOEMHML6X8QC5058; JSESSIONID=0000u6QnCl9DTQaxTTMG_SRcSEB:14nuu9h0k; NSC_xfc_jqw6_qfstjtufodf=00000000234c1f310b110d790a110e1122081e113660",
                    "sec-ch-ua-mobile": "?0",
                    "Sec-Fetch-Dest": "document",
                    "Sec-Fetch-Mode": "navigate",
                    "Sec-Fetch-Site": "same-origin",
                    "Sec-Fetch-User": "?1",
                    "Upgrade-Insecure-Requests": "1",
                    "User-Agent": ua.random
                    }

                    for i in range(0,len(my_df)):    
                        time.sleep(15)
                        key = my_df['href'][i].split('F&primaryKey=')[1]
                        web = 'https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey='+str(key)
                        link = requests.get(web,headers = headers)
                        soup = BeautifulSoup(link.text,features="html.parser") 

                        blue = soup.find_all('th',bgcolor="#DAEBED", width="25%")
                        yellow = soup.find_all('th',bgcolor="#FFFF99", width="25%")
                        green = soup.find_all('th',bgcolor="#CAEDAF", width="25%")
                        orange = soup.find_all('th',bgcolor="#FFDD83", width="25%")
                        alist = blue+yellow+green+orange
                        mylist = []
                        for i in range(0,len(alist)):
                            txt = alist[i].text.replace('\r','').replace('\t','').replace('\n','')
                            mylist+=[txt]

                        blist = soup.find_all('td', bgcolor="#EFF1F1",width="75%")[0:len(mylist)]
                        content = []
                        for i in range(0,len(blist)):
                            txt = blist[i].text.replace('\r','').replace('\t','').replace('\n','')
                            content+=[txt]    
                        mylist = mylist + ['連結']
                        content = content + [web]

                        one_case = pd.DataFrame({
                            'content':content
                        },index = mylist)

                        cases = pd.concat([cases,one_case],axis = 1)

                    cases = cases.transpose()

                    df = pd.DataFrame({
                        'Status':'',
                        '發起人':'Sean',
                        '電子領標':'Rosenna',
                        '電子領標日':'',
                        '公告日':list(cases['公告日']),
                        '截止投標':list(cases['截止投標']),
                        '開標時間':list(cases['開標時間']),
                        '金額':list(cases['預算金額']),
                        'WD':'',
                        '專案結束日':'',
                        '招標方式':list(cases['招標方式']),
                        '決標方式':list(cases['決標方式']),
                        '機關名稱':list(cases['機關名稱']),
                        '單位名稱':list(cases['單位名稱']),
                        '標案名稱':list(cases['標案名稱']),
                        '聯絡人':list(cases['聯絡人']),
                        '聯絡電話':list(cases['聯絡電話']),
                        '電子郵件信箱':list(cases['電子郵件信箱']),
                        '標的分類':list(cases['標的分類']),
                        '連結':list(cases['連結']),
                        '關鍵字':key_word
                    })
                except:
                    df = pd.DataFrame([])

                final_df = pd.concat([final_df,df])

            final_df = final_df.drop_duplicates(subset = '標案名稱').reset_index().drop(columns = 'index')

            d = final_df['公告日'].copy()
            for i in range(len(d)):
                year = str(int(d[i].split('/')[0])+1911)
                d[i]=year+d[i].split('/')[1]+d[i].split('/')[2]
            d=pd.to_datetime(d,format='%Y%m%d')
            final_df['date'] = d
            final_df = final_df.sort_values(by = 'date',ascending = False)
            final_df = final_df.drop(columns = 'date')
            sd = start_date.split('/')[0]+start_date.split('/')[1]+start_date.split('/')[2]
            ed = end_date.split('/')[0]+end_date.split('/')[1]+end_date.split('/')[2]
            
            final_df.to_csv('C:/Users/Administrator/Desktop/EY_WebCrawler/標案資料最新紀錄.csv',index = None,encoding = 'utf-8_sig')
            final_df.to_csv('C:/Users/Administrator/Desktop/EY_WebCrawler/Daily Bid Data/標案資料'+sd+'-'+ed+'.csv',index = None,encoding = 'utf-8_sig')
            scenario = 3
        elif YN=='N':
            print('結束程式')
            scenario = 4
    except:
        logging.basicConfig(handlers=[logging.FileHandler(filename, 'a', 'utf-8')],level=logging.ERROR, format=FORMAT)
        logging.error('Catch an exception.', exc_info=True)   
        scenario = 5     

#寄信
content = MIMEMultipart()  #建立MIMEMultipart物件

if scenario==1:
    fileToSend = 'C:/Users/Administrator/Desktop/EY_WebCrawler/Daily Bid Data/標案資料'+sd+'-'+ed+'.csv'
    content["subject"] = today+"標案資料更新"  
    part = MIMEText("今日標案資料更新已完成，附檔為今日進度", _charset="UTF-8")
elif scenario==2:
    fileToSend =  filename  
    content["subject"] = today+"標案資料更新錯誤匯報"  
    part = MIMEText("今日標案資料更新發生異常！請參閱附檔的錯誤報告。", _charset="UTF-8")
elif scenario==3:
    fileToSend = 'C:/Users/Administrator/Desktop/EY_WebCrawler/Daily Bid Data/標案資料'+sd+'-'+ed+'.csv'
    content["subject"] = today+"標案資料更新"  
    part = MIMEText("今日標案資料更新已完成，附檔為今日進度", _charset="UTF-8")
elif scenario==4:
    quit()
elif scenario==5:
    fileToSend =  filename  
    content["subject"] = today+"標案資料更新錯誤匯報"  
    part = MIMEText("今日標案資料更新發生異常！請參閱附檔的錯誤報告。", _charset="UTF-8")

content["from"] = "show19970117@gmail.com"  #寄件者
content["to"] = "show19970117@gmail.com" #收件者
content.attach(part)
import smtplib
ctype, encoding = mimetypes.guess_type(fileToSend)
if ctype is None or encoding is not None:
    ctype = "application/octet-stream"
maintype, subtype = ctype.split("/", 1)

fp = open(fileToSend,encoding = 'utf-8')
attachment = MIMEText(fp.read(), _subtype=subtype)
fp.close()

with smtplib.SMTP(host="smtp.gmail.com", port="587") as smtp:  # 設定SMTP伺服器
    try:
        smtp.ehlo()  # 驗證SMTP伺服器
        smtp.starttls()  # 建立加密傳輸
        smtp.login("show19970117@gmail.com", "bzepnhyogerzztxv")  # 登入寄件者gmail
        smtp.send_message(content)  # 寄送郵件
        print("Complete!")
    except Exception as e:
        print("Error message: ", e)
# Out:
# Error occurred during loading data. Trying to use cache server https://fake-useragent.herokuapp.com/browsers/0.1.11
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\fake_useragent\utils.py", line 154, in load
#     for item in get_browsers(verify_ssl=verify_ssl):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\fake_useragent\utils.py", line 99, in get_browsers
#     html = html.split('<table class="w3-table-all notranslate">')[1]
# IndexError: list index out of range
# ---------------開始行銷標案爬蟲---------------
# 總共5筆資料,預計約1.25分鐘後完成
# ---------------開始數據標案爬蟲---------------
# 總共3筆資料,預計約0.75分鐘後完成
# ---------------開始顧問標案爬蟲---------------
# 總共2筆資料,預計約0.5分鐘後完成
# ---------------開始分析標案爬蟲---------------
# 總共17筆資料,預計約4.25分鐘後完成
# Complete!

# %%
fp = open(fileToSend, encoding = 'utf-8')
fp.read()
# Out:
# '\ufeffStatus,發起人,電子領標,電子領標日,公告日,截止投標,開標時間,金額,WD,專案結束日,招標方式,決標方式,機關名稱,單位名稱,標案名稱,聯絡人,聯絡電話,電子郵件信箱,標的分類,連結,關鍵字\n,Sean,Rosenna,,110/06/28,110/07/05 17:00,,"500,000元",,,公開取得報價單或企劃書,參考最有利標精神,財團法人中華民國對外貿易發展協會,數位商務處,台灣經貿網數位行銷廣告投放服務,馮德芬/彭嘉琦,(02)27255200分機1616/3963,mikifeng@taitra.org.tw,勞務類871-廣告服務,https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53507963,行銷\n,Sean,Rosenna,,110/06/28,110/07/05 11:00,110/07/05 14:00,"580,000元",,,公開取得報價單或企劃書,最低標,行政院農業委員會農業試驗所,秘書室/作物組,水稻特徵蒐集、巨量基因體生資分析與計畫管考勞務承攬,陳小姐/吳先生(規格),(04)23317215,killua0284@tari.gov.tw,勞務類85-研發服務,https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53508442,分析\n,Sean,Rosenna,,110/06/28,110/07/05 17:00,110/07/06 10:00,"9,941,344元",,,公開招標,最低標,衛生福利部屏東醫院,衛生福利部屏東醫院,細菌鑑定與抗生素敏感性試驗自動化分析儀器之檢驗試劑,張雪卿,(08)7363011分機2253,geaf0311@pntn.mohw.gov.tw,財物類352-醫藥產品,https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53507429,分析\n,Sean,Rosenna,,110/06/28,110/07/13 09:00,110/07/13 10:00,"1,785,000元",,,公開招標,最低標,台灣自來水股份有限公司第三區管理處,發包中心,明德淨水場錳分析監測計1組 (含安裝及試車),卓佩珍,(03)5712141分機793,jen0702@mail.water.gov.tw,財物類482-做為測量、檢查、航行及其他目的用之儀器和裝置，除光學儀器; 工業程序控制設備; 上述各項之零件及附件,https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53507462,分析\n,Sean,Rosenna,,110/06/28,110/07/05 17:00,110/07/06 14:00,,,,公開招標,最低標,台灣中油股份有限公司,採購處南部採購中心採購一組,掌上型可攜式馬達分析儀器一套,歐政谷,(07)5824141分機3408,708569@cpc.com.tw,財物類482-做為測量、檢查、航行及其他目的用之儀器和裝置，除光學儀器; 工業程序控制設備; 上述各項之零件及附件,https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53507856,分析\n,Sean,Rosenna,,110/06/28,110/07/12 17:00,110/07/13 10:00,"3,950,000元",,,限制性招標(經公開評選或公開徵求),準用最有利標,桃園市政府文化局,桃園市政府文化局文創影視科,2021年桃園藝術亮點叢書編印與行銷計畫委託專業服務案,溫小姐,(03)3322592分機8709,10019593@mail.tycg.gov.tw,"勞務類96-娛樂,文化,體育服務",https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53507637,行銷\n,Sean,Rosenna,,110/06/28,110/07/12 17:00,110/07/13 10:00,"1,280,000元",,,公開招標,最低標,國立陽明交通大學,總務處/圖書儀器購運組,動作分析軟體系統租賃,張綺真,(03)5712121分機52103,s0706@nctu.edu.tw,財物類482-做為測量、檢查、航行及其他目的用之儀器和裝置，除光學儀器; 工業程序控制設備; 上述各項之零件及附件,https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53508220,分析\n,Sean,Rosenna,,110/06/28,110/07/05 17:00,110/07/06 09:00,"350,000元",,,公開取得報價單或企劃書,最低標,衛生福利部臺南醫院,衛生福利部臺南醫院,『身體組成分析儀』1台採購案,張良慶,(06)2200055分機2503,00928@tnhosp.mohw.gov.tw,"財物類481-醫療, 外科及矯形設備",https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53508342,分析\n,Sean,Rosenna,,110/06/28,110/07/13 08:30,110/07/13 10:00,"1,000,000元",,,公開招標,最低標,國防醫學院,三軍總醫院,脈衝式震盪分析儀,劉忠強,(02)87923311分機16944,diyun1213@mail.ndmctsgh.edu.tw,"財物類481-醫療, 外科及矯形設備",https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53507891,分析\n,Sean,Rosenna,,110/06/28,110/07/26 17:00,110/07/27 09:30,"609,592,667元",,,限制性招標(經公開評選或公開徵求),準用最有利標,高雄市政府,高雄市政府工務局新建工程處,加速高雄煉油廠工廠區(不含第三區）污染改善工作委託總顧問技術服務,林佑俊,(07)3368333分機2315,oatow@kcg.gov.tw,勞務類94-污水及垃圾處理、公共衛生及其他環保服務,https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53507255,顧問\n,Sean,Rosenna,,110/06/28,110/07/12 17:00,110/07/13 15:00,"4,800,000元",,,公開招標,最低標,國防部軍事情報局,國防部軍事情報局,數據訊號轉換設備,吳東隆,(02)28311032,mibbuying@mail.mil.tw,財物類449-其他特殊用途之機具及其零件,https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53507729,數據\n,Sean,Rosenna,,110/06/25,110/07/26 17:30,110/07/27 09:30,"18,500,000元",,,限制性招標(經公開評選或公開徵求),準用最有利標,行政院環境保護署,監資處,110-112年空氣品質數據蒐集處理及整合強化計畫,謝維紋 許惠琮,(02)23117722分機2386 2456,weiwen.hsieh@epa.gov.tw,勞務類842-軟體執行服務,https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53506251,數據\n,Sean,Rosenna,,110/06/25,110/07/05 17:00,110/07/06 14:00,,,,限制性招標(經公開評選或公開徵求),最低標,台灣中油股份 ...
